# %%
f = open("flattened_img.txt", "r")
bin_img = []
r = []
for x in f:
  bin_img.append(np.binary_repr(int(x), width=24))
  r.append(x)

# %%
import numpy as np

# %%
len(r)
# Out:
# 263169

# %%
f1 = open('bin_img.txt', 'w')
for num in bin_img:
        f1.write(num)
        f1.write('\n')

# %%
len(bin_img)
# Out:
# 263169

# %%
# A = [21, 512, 21, 512, 21,4,21,263169,21,4,21,4,8,10, 16,8,8,8,7,21,8,3,15,8,8,9,8,3,14,11,8,8,10,8,3,14,11,8,8,11,8,3,14,11,8,8,11,8,3,14,11,8,8,9,11,8,3,11,8,8,10,11,8,3,11,8,8,12,8,3,11,8,8,9,12,8,3,11,8,8,10,12,8,3,11,13,8,8,5,8,9,8,8,11,8,8,17,8,11,8,8,17]

# %%
len(b)
# Out:
# 108

# %%
f1 = open('OPCODES_ASSEMBLY.txt', 'r')
a = []
b = []
for num in f1:
    # print(num.replace("\t", ""))
    b.append(num.replace("\t", ""))
    a.append(int(num.replace("\t", ""),2))

# %%
f1 = open('opcodes.txt', 'w')
for num in b:
    f1.write(str(num))
    f1.write('\n')

# %%
num
# Out:
# '0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t0\t1\t1\t0\t0'

# %%
int('010101', 2)
# Out:
# 21

# %%
f1 = open('memory_hex.txt', 'r')
a = []
c =0
for num in f1:
    # print(num.replace("\t", ""))
    # b.append(num.replace("\t", ""))
    try:
        a.append(int(num,2))
    except:
        c += 1

# %%
len(a)
# Out:
# 16886

# %%
c
# Out:
# 115

# %%
a
# Out:
# [160,
#  163,
#  158,
#  156,
#  156,
#  156,
#  154,
#  155,
#  160,
#  165,
#  172,
#  171,
#  169,
#  151,
#  130,
#  99,
#  91,
#  100,
#  105,
#  109,
#  105,
#  108,
#  109,
#  109,
#  105,
#  109,
#  113,
#  116,
#  123,
#  125,
#  123,
#  131,
#  129,
#  133,
#  131,
#  131,
#  130,
#  129,
#  132,
#  131,
#  133,
#  133,
#  134,
#  134,
#  132,
#  133,
#  133,
#  134,
#  136,
#  136,
#  135,
#  136,
#  134,
#  130,
#  131,
#  130,
#  133,
#  132,
#  131,
#  134,
#  133,
#  133,
#  130,
#  139,
#  131,
#  131,
#  133,
#  128,
#  128,
#  130,
#  129,
#  127,
#  129,
#  127,
#  128,
#  123,
#  120,
#  117,
#  112,
#  105,
#  123,
#  140,
#  152,
#  159,
#  160,
#  150,
#  152,
#  153,
#  155,
#  157,
#  154,
#  153,
#  153,
#  152,
#  155,
#  153,
#  157,
#  156,
#  157,
#  154,
#  189,
#  211,
#  217,
#  218,
#  190,
#  109,
#  105,
#  115,
#  118,
#  124,
#  120,
#  121,
#  122,
#  120,
#  121,
#  122,
#  123,
#  126,
#  124,
#  124,
#  127,
#  124,
#  125,
#  118,
#  117,
# ...
